# %%
import pandas as pd
# Out:
# C:\Users\sivaluxan\Anaconda3\envs\tf-gpu\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\sivaluxan\Anaconda3\envs\tf-gpu\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\sivaluxan\Anaconda3\envs\tf-gpu\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
combine_data=pd.read_csv(r"C:\Users\sivaluxan\Desktop\FYP-2021\FYP\ENTC_17_FYP_26\stress_data_collection\updated_dataset_1\combine\combine_data.csv")
questionnaire_data=pd.read_csv(r"C:\Users\sivaluxan\Desktop\FYP-2021\FYP\ENTC_17_FYP_26\stress_data_collection\questionaire_data\Questionnaire-Blok-Results_final-performance.csv")
# Out:
# C:\Users\sivaluxan\Anaconda3\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
print(combine_data.shape)
print(questionnaire_data.shape)
# Out:
# (655608, 68)
# (89, 47)

# %%
questionnaire_data.head(10)
# Out:
#     PP  Blok Condition  Unnamed: 3  Valence  Valence_recorded  Arousal  \
# 0  NaN   NaN       NaN         NaN      NaN               NaN      NaN
# 1   SP   1.0         N         NaN      6.0               3.0      3.0
# 2   SP   2.0         I         NaN      4.0               5.0      5.0
# 3   SP   3.0         T         NaN      3.0               6.0      3.0
# 4   MP   1.0         N         NaN      2.0               7.0      4.0
# 5   MP   2.0         T         NaN      5.0               4.0      3.0
# 6   MP   3.0         I         NaN      3.0               6.0      5.0
# 7    1   1.0         N         NaN      4.0               5.0      6.0
# 8    1   2.0         T         NaN      4.0               5.0      5.0
# 9    1   3.0         I         NaN      5.0               4.0      3.0
#
#    Arousal_recorded  Dominance  Unnamed: 9  ...  DifficultReport2  \
# 0               NaN        NaN         NaN  ...               NaN
# 1               6.0        5.0         NaN  ...                 2
# 2               4.0        7.0         NaN  ...                 4
# 3               6.0        3.0         NaN  ...                 5
# 4               5.0        5.0         NaN  ...                 3
# 5               6.0        4.0         NaN  ...                 5
# 6               4.0        7.0         NaN  ...                 2
# 7               3.0        6.0         NaN  ...                 0
# 8               4.0        7.0         NaN  ...                 1
# 9               6.0        4.0         NaN  ...                 1
#
#    DifficultPresentation  Average of done  Unnamed: 40  InterestTopic1  \
# 0                    NaN              NaN          NaN             NaN
# 1                      0              NaN          NaN               3
# 2                      1              NaN          NaN               1
# 3                      1              NaN          NaN               1
# 4                      1              NaN          NaN               4
# 5                      2              NaN          NaN               3
# 6                      1              NaN          NaN               4
# 7                     **              0.5          NaN               3
# 8                      1              1.3          NaN               4
# 9                      0              1.0          NaN               3
#
#    InterestTopic2  Average over done  Unnamed: 44  Unnamed: 45  \
# 0             NaN                NaN          NaN          NaN
# 1               3                NaN          NaN          NaN
# 2               5                NaN          NaN          NaN
# 3               0                NaN          NaN          NaN
# 4               5                NaN          NaN          NaN
# 5               4                NaN          NaN          NaN
# 6               4                NaN          NaN          NaN
# 7               5                4.0          NaN          NaN
# 8               3                3.5          NaN          NaN
# 9               4                3.5          NaN          NaN
#
#                                             Comments
# 0                                                NaN
# 1            Unclear expectations regarding reports.
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                   Niet aan presentatie toegekomen.
# 8  Beter verdelen van de tijd over de 3 taken. Ik...
# 9  Prioriteiten stellen in het geval van mail. Ve...
#
# [10 rows x 47 columns]

# %%
combine_data.head(10)
# Out:
#   timestampSkeletal Spine ShoulderCenter Head ShoulderLeft ShoulderRight  \
# 0                 0   NaN            NaN  NaN          NaN           NaN
# 1                 0   NaN            NaN  NaN          NaN           NaN
# 2                 0   NaN            NaN  NaN          NaN           NaN
# 3                 0   NaN            NaN  NaN          NaN           NaN
# 4                 0   NaN            NaN  NaN          NaN           NaN
# 5                 0   NaN            NaN  NaN          NaN           NaN
# 6                 0   NaN            NaN  NaN          NaN           NaN
# 7                 0   NaN            NaN  NaN          NaN           NaN
# 8                 0   NaN            NaN  NaN          NaN           NaN
# 9                 0   NaN            NaN  NaN          NaN           NaN
#
#   ElbowLeft WristLeft HandLeft ElbowRight  ... Action Unit 17 - Chin Raiser  \
# 0       NaN       NaN      NaN        NaN  ...                  FIND_FAILED
# 1       NaN       NaN      NaN        NaN  ...                   FIT_FAILED
# 2       NaN       NaN      NaN        NaN  ...                   FIT_FAILED
# 3       NaN       NaN      NaN        NaN  ...                    NotActive
# 4       NaN       NaN      NaN        NaN  ...                    NotActive
# 5       NaN       NaN      NaN        NaN  ...                  FIND_FAILED
# 6       NaN       NaN      NaN        NaN  ...                   FIT_FAILED
# 7       NaN       NaN      NaN        NaN  ...                   FIT_FAILED
# 8       NaN       NaN      NaN        NaN  ...                    NotActive
# 9       NaN       NaN      NaN        NaN  ...                   FIT_FAILED
#
#   Action Unit 20 - Lip Stretcher Action Unit 23 - Lip Tightener  \
# 0                    FIND_FAILED                    FIND_FAILED
# 1                     FIT_FAILED                     FIT_FAILED
# 2                     FIT_FAILED                     FIT_FAILED
# 3                      NotActive                      NotActive
# 4                      NotActive                      NotActive
# 5                    FIND_FAILED                    FIND_FAILED
# 6                     FIT_FAILED                     FIT_FAILED
# 7                     FIT_FAILED                     FIT_FAILED
# 8                      NotActive                      NotActive
# 9                     FIT_FAILED                     FIT_FAILED
#
#   Action Unit 24 - Lip Pressor Action Unit 25 - Lips Part  \
# 0                  FIND_FAILED                FIND_FAILED
# 1                   FIT_FAILED                 FIT_FAILED
# 2                   FIT_FAILED                 FIT_FAILED
# 3                    NotActive                          D
# 4                    NotActive                          D
# 5                  FIND_FAILED                FIND_FAILED
# 6                   FIT_FAILED                 FIT_FAILED
# 7                   FIT_FAILED                 FIT_FAILED
# 8                    NotActive                  NotActive
# 9                   FIT_FAILED                 FIT_FAILED
#
#   Action Unit 26 - Jaw Drop Action Unit 27 - Mouth Stretch  \
# 0               FIND_FAILED                    FIND_FAILED
# 1                FIT_FAILED                     FIT_FAILED
# 2                FIT_FAILED                     FIT_FAILED
# 3                 NotActive                              C
# 4                 NotActive                              A
# 5               FIND_FAILED                    FIND_FAILED
# 6                FIT_FAILED                     FIT_FAILED
# 7                FIT_FAILED                     FIT_FAILED
# 8                 NotActive                      NotActive
# 9                FIT_FAILED                     FIT_FAILED
#
#   Action Unit 43 - Eyes Closed    PP Block
# 0                  FIND_FAILED  PP10   2.0
# 1                   FIT_FAILED  PP10   3.0
# 2                   FIT_FAILED  PP11   1.0
# 3                    NotActive  PP11   3.0
# 4                    NotActive  PP11   3.0
# 5                  FIND_FAILED  PP12   1.0
# 6                   FIT_FAILED  PP12   2.0
# 7                   FIT_FAILED  PP12   2.0
# 8                    NotActive  PP13   1.0
# 9                   FIT_FAILED  PP13   3.0
#
# [10 rows x 68 columns]

# %%
combine_data[(combine_data['PP']=='PP23') & (combine_data['Block']==2)]
# Out:
#        timestampSkeletal                               Spine  \
# 33                     0                                 NaN
# 574563         265954860                                 NaN
# 574564         265955062                                 NaN
# 574565         265955264                                 NaN
# 574566         265955660                                 NaN
# ...                  ...                                 ...
# 587841         269277496   (0,1947823 / 0,275575 / 2,172067)
# 587842         269277898  (0,1854329 / 0,2738599 / 2,171323)
# 587843         269278098  (0,1842027 / 0,2669772 / 2,174869)
# 587844         269278296  (0,1854803 / 0,2617615 / 2,178776)
# 587845         269278498  (0,1871983 / 0,2584569 / 2,180191)
#
#                             ShoulderCenter  \
# 33                                     NaN
# 574563                                 NaN
# 574564                                 NaN
# 574565                                 NaN
# 574566                                 NaN
# ...                                    ...
# 587841   (0,232249 / 0,4166324 / 2,136737)
# 587842  (0,2180766 / 0,4187594 / 2,136156)
# 587843  (0,2123202 / 0,4131745 / 2,146872)
# 587844  (0,2086658 / 0,4094868 / 2,154371)
# 587845  (0,2066478 / 0,4078043 / 2,157646)
#
#                                       Head  \
# 33                                     NaN
# 574563                                 NaN
# 574564                                 NaN
# 574565                                 NaN
# 574566                                 NaN
# ...                                    ...
# 587841  (0,2521452 / 0,5468605 / 2,108393)
# 587842  (0,2416217 / 0,5504197 / 2,111575)
# 587843   (0,237964 / 0,5502621 / 2,112176)
# 587844  (0,2350151 / 0,5495296 / 2,112231)
# 587845  (0,2327539 / 0,5486811 / 2,111732)
#
#                                ShoulderLeft  \
# 33                                      NaN
# 574563                                  NaN
# 574564                                  NaN
# 574565                                  NaN
# 574566                                  NaN
# ...                                     ...
# 587841    (0,1056643 / 0,3658068 / 2,20045)
# 587842   (0,0945647 / 0,3656102 / 2,206898)
# 587843  (0,09341699 / 0,3652969 / 2,208157)
# 587844  (0,09447885 / 0,3624598 / 2,205545)
# 587845  (0,09694503 / 0,3559006 / 2,194605)
#
#                              ShoulderRight  \
# 33                                     NaN
# 574563                                 NaN
# 574564                                 NaN
# 574565                                 NaN
# 574566                                 NaN
# ...                                    ...
# 587841  (0,3018987 / 0,3414622 / 2,010968)
# 587842  (0,2916396 / 0,3407348 / 2,008878)
# 587843  (0,2859788 / 0,3366756 / 2,017722)
# 587844    (0,281772 / 0,3333438 / 2,02567)
# 587845       (0,279319 / 0,33152 / 2,0298)
#
#                                   ElbowLeft  \
# 33                                      NaN
# 574563                                  NaN
# 574564                                  NaN
# 574565                                  NaN
# 574566                                  NaN
# ...                                     ...
# 587841  (0,04615638 / 0,2398536 / 2,157127)
# 587842   (0,1952706 / 0,3020781 / 2,039484)
# 587843   (0,2069346 / 0,3038363 / 2,032038)
# 587844   (0,2081013 / 0,3000306 / 2,029298)
# 587845   (0,2061972 / 0,2943608 / 2,022935)
#
#                                   WristLeft  \
# 33                                      NaN
# 574563                                  NaN
# 574564                                  NaN
# 574565                                  NaN
# 574566                                  NaN
# ...                                     ...
# 587841  (0,01836473 / 0,08665293 / 2,11806)
# 587842   (0,3683966 / 0,2105951 / 1,974071)
# 587843    (0,372335 / 0,2100728 / 1,975333)
# 587844   (0,3575161 / 0,1908008 / 1,993372)
# 587845   (0,3630948 / 0,1928911 / 1,986573)
#
#                                      HandLeft  \
# 33                                        NaN
# 574563                                    NaN
# 574564                                    NaN
# 574565                                    NaN
# 574566                                    NaN
# ...                                       ...
# 587841  (0,009491079 / 0,03216144 / 2,101406)
# 587842     (0,4117743 / 0,2099535 / 1,967161)
# 587843     (0,4211344 / 0,2301555 / 1,965251)
# 587844       (0,408861 / 0,2278291 / 1,98314)
# 587845     (0,4049425 / 0,2209517 / 1,976545)
#
#                                 ElbowRight  ... Action Unit 17 - Chin Raiser  \
# 33                                     NaN  ...                    NotActive
# 574563                                 NaN  ...                    NotActive
# 574564                                 NaN  ...                    NotActive
# 574565                                 NaN  ...                    NotActive
# 574566                                 NaN  ...                    NotActive
# ...                                    ...  ...                          ...
# 587841   (0,1512187 / 0,223083 / 1,990767)  ...                    NotActive
# 587842  (0,2582686 / 0,1985607 / 2,021619)  ...                    NotActive
# 587843  (0,3468865 / 0,1773709 / 1,999874)  ...                    NotActive
# 587844  (0,3647363 / 0,1708728 / 1,992983)  ...                   FIT_FAILED
# 587845  (0,3663273 / 0,1672195 / 1,997457)  ...                  FIND_FAILED
#
#        Action Unit 20 - Lip Stretcher Action Unit 23 - Lip Tightener  \
# 33                          NotActive                      NotActive
# 574563                      NotActive                      NotActive
# 574564                      NotActive                      NotActive
# 574565                      NotActive                      NotActive
# 574566                      NotActive                      NotActive
# ...                               ...                            ...
# 587841                      NotActive                      NotActive
# 587842                      NotActive                      NotActive
# 587843                      NotActive                      NotActive
# 587844                     FIT_FAILED                     FIT_FAILED
# 587845                    FIND_FAILED                    FIND_FAILED
#
#        Action Unit 24 - Lip Pressor Action Unit 25 - Lips Part  \
# 33                        NotActive                  NotActive
# 574563                    NotActive                  NotActive
# 574564                    NotActive                  NotActive
# 574565                    NotActive                  NotActive
# 574566                    NotActive                  NotActive
# ...                             ...                        ...
# 587841                    NotActive                  NotActive
# 587842                    NotActive                  NotActive
# 587843                    NotActive                  NotActive
# 587844                   FIT_FAILED                 FIT_FAILED
# 587845                  FIND_FAILED                FIND_FAILED
#
#        Action Unit 26 - Jaw Drop Action Unit 27 - Mouth Stretch  \
# 33                     NotActive                      NotActive
# 574563                 NotActive                      NotActive
# 574564                 NotActive                      NotActive
# 574565                 NotActive                      NotActive
# 574566                 NotActive                      NotActive
# ...                          ...                            ...
# 587841                 NotActive                      NotActive
# 587842                 NotActive                      NotActive
# 587843                 NotActive                      NotActive
# 587844                FIT_FAILED                     FIT_FAILED
# 587845               FIND_FAILED                    FIND_FAILED
#
#        Action Unit 43 - Eyes Closed    PP Block
# 33                        NotActive  PP23   2.0
# 574563                    NotActive  PP23   2.0
# 574564                    NotActive  PP23   2.0
# 574565                    NotActive  PP23   2.0
# 574566                    NotActive  PP23   2.0
# ...                             ...   ...   ...
# 587841                            A  PP23   2.0
# 587842                            A  PP23   2.0
# 587843                    NotActive  PP23   2.0
# 587844                   FIT_FAILED  PP23   2.0
# 587845                  FIND_FAILED  PP23   2.0
#
# [13284 rows x 68 columns]

# %%
print(combine_data.columns)
print(len(combine_data.columns))
print(len(set(combine_data.columns)))
# Out:
# Index(['timestampSkeletal', 'Spine', 'ShoulderCenter', 'Head', 'ShoulderLeft',
#        'ShoulderRight', 'ElbowLeft', 'WristLeft', 'HandLeft', 'ElbowRight',
#        'WristRight', 'HandRight', 'HipCenter', 'HipLeft', 'HipRight',
#        'KneeLeft', 'AnkleLeft', 'FootLeft', 'KneeRight', 'AnkleRight',
#        'FootRight', 'Video Time', 'Neutral', 'Happy', 'Sad', 'Angry',
#        'Surprised', 'Scared', 'Disgusted', 'Valence', 'Gender', 'Age', 'Beard',
#        'Moustache', 'Glasses', 'Ethnicity', 'Y - Head Orientation',
#        'X - Head Orientation', 'Z - Head Orientation', 'Landmarks', 'Quality',
#        'Mouth', 'Left Eye', 'Right Eye', 'Left Eyebrow', 'Right Eyebrow',
#        'Gaze Direction', 'Action Unit 01 - Inner Brow Raiser',
#        'Action Unit 02 - Outer Brow Raiser', 'Action Unit 04 - Brow Lowerer',
#        'Action Unit 05 - Upper Lid Raiser', 'Action Unit 06 - Cheek Raiser',
#        'Action Unit 07 - Lid Tightener', 'Action Unit 09 - Nose Wrinkler',
#        'Action Unit 10 - Upper Lip Raiser',
#        'Action Unit 12 - Lip Corner Puller', 'Action Unit 14 - Dimpler',
#        'Action Unit 15 - Lip Corner Depressor', 'Action Unit 17 - Chin Raiser',
#        'Action Unit 20 - Lip Stretcher', 'Action Unit 23 - Lip Tightener',
#        'Action Unit 24 - Lip Pressor', 'Action Unit 25 - Lips Part',
#        'Action Unit 26 - Jaw Drop', 'Action Unit 27 - Mouth Stretch',
#        'Action Unit 43 - Eyes Closed', 'PP', 'Block'],
#       dtype='object')
# 68
# 68

# %%
df_participant_dict={'PP1':{'block1':1,'block2':2,'block3':3},'PP2':{'block1':1,'block2':2,'block3':3},'PP3':{'block1':1,'block2':2,'block3':3},
'PP4':{'block1':1,'block2':2,'block3':3},'PP5':{'block1':1,'block2':2,'block3':3},'PP6':{'block1':1,'block2':2,'block3':3},'PP7':{'block1':1,'block2':2,'block3':3},
'PP8':{'block1':1,'block2':2,'block3':3},'PP9':{'block1':1,'block2':2,'block3':3},'PP10':{'block1':1,'block2':2,'block3':3},'PP11':{'block1':1,'block2':2,'block3':3},
'PP12':{'block1':1,'block2':2,'block3':3},'PP13':{'block1':1,'block2':2,'block3':3},'PP14':{'block1':1,'block2':2,'block3':3},'PP15':{'block1':1,'block2':2,'block3':3},
'PP16':{'block1':1,'block2':2,'block3':3},'PP17':{'block1':1,'block2':2,'block3':3},'PP18':{'block1':1,'block2':2,'block3':3},'PP19':{'block1':1,'block2':2,'block3':3}, 
'PP20':{'block1':1,'block2':2,'block3':3},'PP21':{'block1':1,'block2':2,'block3':3},'PP22':{'block1':1,'block2':2,'block3':3},'PP23':{'block1':1,'block2':2,'block3':3}, 
'PP24':{'block1':1,'block2':2,'block3':3},'PP25':{'block1':1,'block2':2,'block3':3}}

for i in range(1,26):
    for j in range(1,4):
        #Valence_1_2=questionnaire_data[(questionnaire_data['PP']==str(i)) & (questionnaire_data['Blok']==j)]['Valence'].values[0]
        Condition_1_2=questionnaire_data[(questionnaire_data['PP']==str(i)) & (questionnaire_data['Blok']==j)]['Condition'].values[0]
        Valence_recorded_1_2=questionnaire_data[(questionnaire_data['PP']==str(i)) & (questionnaire_data['Blok']==j)]['Valence_recorded'].values[0]
        #Arousal_1_2=questionnaire_data[(questionnaire_data['PP']==str(i)) & (questionnaire_data['Blok']==j)]['Arousal'].values[0]
        Arousal_recorded_1_2=questionnaire_data[(questionnaire_data['PP']==str(i)) & (questionnaire_data['Blok']==j)]['Arousal_recorded'].values[0]
        Dominance_1_2=questionnaire_data[(questionnaire_data['PP']==str(i)) & (questionnaire_data['Blok']==j)]['Dominance'].values[0]
        Stress_1_2=questionnaire_data[(questionnaire_data['PP']==str(i)) & (questionnaire_data['Blok']==j)]['Stress'].values[0]
        MentalEffort_1_2=questionnaire_data[(questionnaire_data['PP']==str(i)) & (questionnaire_data['Blok']==j)]['MentalEffort'].values[0]
        MentalDemand_1_2=questionnaire_data[(questionnaire_data['PP']==str(i)) & (questionnaire_data['Blok']==j)]['MentalDemand'].values[0]
        PhysicalDemand_1_2=questionnaire_data[(questionnaire_data['PP']==str(i)) & (questionnaire_data['Blok']==j)]['PhysicalDemand'].values[0]
        TemporalDemand_1_2=questionnaire_data[(questionnaire_data['PP']==str(i)) & (questionnaire_data['Blok']==j)]['TemporalDemand'].values[0]
        Effort_1_2=questionnaire_data[(questionnaire_data['PP']==str(i)) & (questionnaire_data['Blok']==j)]['Effort'].values[0]
        Performance_1_2=questionnaire_data[(questionnaire_data['PP']==str(i)) & (questionnaire_data['Blok']==j)]['Performance'].values[0]
        Performance_recorded_1_2=questionnaire_data[(questionnaire_data['PP']==str(i)) & (questionnaire_data['Blok']==j)]['Performance_recorded'].values[0]
        Frustration_1_2=questionnaire_data[(questionnaire_data['PP']==str(i)) & (questionnaire_data['Blok']==j)]['Frustration'].values[0]
        df_1=combine_data[(combine_data['PP']=='PP%s'%str(i)) & (combine_data['Block']==j)]
        #df_1['Valence']=Valence_1_2
        df_1['Condition']=Condition_1_2
        df_1['Valence_recorded']=Valence_recorded_1_2
        #df_1['Arousal']=Arousal_1_2
        df_1['Arousal_recorded']=Arousal_recorded_1_2
        df_1['Dominance']=Dominance_1_2
        df_1['Stress']=Stress_1_2
        df_1['MentalEffort']=MentalEffort_1_2
        df_1['MentalDemand']=MentalDemand_1_2
        df_1['PhysicalDemand']=PhysicalDemand_1_2
        df_1['TemporalDemand']=TemporalDemand_1_2
        df_1['Effort']=Effort_1_2
        df_1['Performance']=Performance_1_2
        df_1['Performance_recorded']=Performance_recorded_1_2
        df_1['Frustration']=Frustration_1_2
        if j==1:
            df_participant_dict['PP%s'%str(i)]['block1']=df_1
        elif j==2:
            df_participant_dict['PP%s'%str(i)]['block2']=df_1
        elif j==3:
            df_participant_dict['PP%s'%str(i)]['block3']=df_1
# Out:
# <ipython-input-28-a717959844e5>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Condition']=Condition_1_2
# <ipython-input-28-a717959844e5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Valence_recorded']=Valence_recorded_1_2
# <ipython-input-28-a717959844e5>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Arousal_recorded']=Arousal_recorded_1_2
# <ipython-input-28-a717959844e5>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Dominance']=Dominance_1_2
# <ipython-input-28-a717959844e5>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Stress']=Stress_1_2
# <ipython-input-28-a717959844e5>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalEffort']=MentalEffort_1_2
# <ipython-input-28-a717959844e5>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalDemand']=MentalDemand_1_2
# <ipython-input-28-a717959844e5>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['PhysicalDemand']=PhysicalDemand_1_2
# <ipython-input-28-a717959844e5>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['TemporalDemand']=TemporalDemand_1_2
# <ipython-input-28-a717959844e5>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Effort']=Effort_1_2
# <ipython-input-28-a717959844e5>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance']=Performance_1_2
# <ipython-input-28-a717959844e5>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance_recorded']=Performance_recorded_1_2
# <ipython-input-28-a717959844e5>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Frustration']=Frustration_1_2
# <ipython-input-28-a717959844e5>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Condition']=Condition_1_2
# <ipython-input-28-a717959844e5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Valence_recorded']=Valence_recorded_1_2
# <ipython-input-28-a717959844e5>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Arousal_recorded']=Arousal_recorded_1_2
# <ipython-input-28-a717959844e5>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Dominance']=Dominance_1_2
# <ipython-input-28-a717959844e5>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Stress']=Stress_1_2
# <ipython-input-28-a717959844e5>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalEffort']=MentalEffort_1_2
# <ipython-input-28-a717959844e5>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalDemand']=MentalDemand_1_2
# <ipython-input-28-a717959844e5>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['PhysicalDemand']=PhysicalDemand_1_2
# <ipython-input-28-a717959844e5>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['TemporalDemand']=TemporalDemand_1_2
# <ipython-input-28-a717959844e5>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Effort']=Effort_1_2
# <ipython-input-28-a717959844e5>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance']=Performance_1_2
# <ipython-input-28-a717959844e5>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance_recorded']=Performance_recorded_1_2
# <ipython-input-28-a717959844e5>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Frustration']=Frustration_1_2
# <ipython-input-28-a717959844e5>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Condition']=Condition_1_2
# <ipython-input-28-a717959844e5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Valence_recorded']=Valence_recorded_1_2
# <ipython-input-28-a717959844e5>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Arousal_recorded']=Arousal_recorded_1_2
# <ipython-input-28-a717959844e5>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Dominance']=Dominance_1_2
# <ipython-input-28-a717959844e5>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Stress']=Stress_1_2
# <ipython-input-28-a717959844e5>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalEffort']=MentalEffort_1_2
# <ipython-input-28-a717959844e5>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalDemand']=MentalDemand_1_2
# <ipython-input-28-a717959844e5>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['PhysicalDemand']=PhysicalDemand_1_2
# <ipython-input-28-a717959844e5>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['TemporalDemand']=TemporalDemand_1_2
# <ipython-input-28-a717959844e5>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Effort']=Effort_1_2
# <ipython-input-28-a717959844e5>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance']=Performance_1_2
# <ipython-input-28-a717959844e5>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance_recorded']=Performance_recorded_1_2
# <ipython-input-28-a717959844e5>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Frustration']=Frustration_1_2
# <ipython-input-28-a717959844e5>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Condition']=Condition_1_2
# <ipython-input-28-a717959844e5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Valence_recorded']=Valence_recorded_1_2
# <ipython-input-28-a717959844e5>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Arousal_recorded']=Arousal_recorded_1_2
# <ipython-input-28-a717959844e5>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Dominance']=Dominance_1_2
# <ipython-input-28-a717959844e5>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Stress']=Stress_1_2
# <ipython-input-28-a717959844e5>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalEffort']=MentalEffort_1_2
# <ipython-input-28-a717959844e5>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalDemand']=MentalDemand_1_2
# <ipython-input-28-a717959844e5>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['PhysicalDemand']=PhysicalDemand_1_2
# <ipython-input-28-a717959844e5>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['TemporalDemand']=TemporalDemand_1_2
# <ipython-input-28-a717959844e5>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Effort']=Effort_1_2
# <ipython-input-28-a717959844e5>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance']=Performance_1_2
# <ipython-input-28-a717959844e5>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance_recorded']=Performance_recorded_1_2
# <ipython-input-28-a717959844e5>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Frustration']=Frustration_1_2
# <ipython-input-28-a717959844e5>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Condition']=Condition_1_2
# <ipython-input-28-a717959844e5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Valence_recorded']=Valence_recorded_1_2
# <ipython-input-28-a717959844e5>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Arousal_recorded']=Arousal_recorded_1_2
# <ipython-input-28-a717959844e5>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Dominance']=Dominance_1_2
# <ipython-input-28-a717959844e5>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Stress']=Stress_1_2
# <ipython-input-28-a717959844e5>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalEffort']=MentalEffort_1_2
# <ipython-input-28-a717959844e5>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalDemand']=MentalDemand_1_2
# <ipython-input-28-a717959844e5>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['PhysicalDemand']=PhysicalDemand_1_2
# <ipython-input-28-a717959844e5>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['TemporalDemand']=TemporalDemand_1_2
# <ipython-input-28-a717959844e5>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Effort']=Effort_1_2
# <ipython-input-28-a717959844e5>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance']=Performance_1_2
# <ipython-input-28-a717959844e5>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance_recorded']=Performance_recorded_1_2
# <ipython-input-28-a717959844e5>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Frustration']=Frustration_1_2
# <ipython-input-28-a717959844e5>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Condition']=Condition_1_2
# <ipython-input-28-a717959844e5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Valence_recorded']=Valence_recorded_1_2
# <ipython-input-28-a717959844e5>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Arousal_recorded']=Arousal_recorded_1_2
# <ipython-input-28-a717959844e5>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Dominance']=Dominance_1_2
# <ipython-input-28-a717959844e5>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Stress']=Stress_1_2
# <ipython-input-28-a717959844e5>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalEffort']=MentalEffort_1_2
# <ipython-input-28-a717959844e5>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalDemand']=MentalDemand_1_2
# <ipython-input-28-a717959844e5>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['PhysicalDemand']=PhysicalDemand_1_2
# <ipython-input-28-a717959844e5>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['TemporalDemand']=TemporalDemand_1_2
# <ipython-input-28-a717959844e5>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Effort']=Effort_1_2
# <ipython-input-28-a717959844e5>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance']=Performance_1_2
# <ipython-input-28-a717959844e5>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance_recorded']=Performance_recorded_1_2
# <ipython-input-28-a717959844e5>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Frustration']=Frustration_1_2
# <ipython-input-28-a717959844e5>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Condition']=Condition_1_2
# <ipython-input-28-a717959844e5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Valence_recorded']=Valence_recorded_1_2
# <ipython-input-28-a717959844e5>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Arousal_recorded']=Arousal_recorded_1_2
# <ipython-input-28-a717959844e5>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Dominance']=Dominance_1_2
# <ipython-input-28-a717959844e5>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Stress']=Stress_1_2
# <ipython-input-28-a717959844e5>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalEffort']=MentalEffort_1_2
# <ipython-input-28-a717959844e5>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalDemand']=MentalDemand_1_2
# <ipython-input-28-a717959844e5>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['PhysicalDemand']=PhysicalDemand_1_2
# <ipython-input-28-a717959844e5>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['TemporalDemand']=TemporalDemand_1_2
# <ipython-input-28-a717959844e5>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Effort']=Effort_1_2
# <ipython-input-28-a717959844e5>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance']=Performance_1_2
# <ipython-input-28-a717959844e5>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance_recorded']=Performance_recorded_1_2
# <ipython-input-28-a717959844e5>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Frustration']=Frustration_1_2
# <ipython-input-28-a717959844e5>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Condition']=Condition_1_2
# <ipython-input-28-a717959844e5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Valence_recorded']=Valence_recorded_1_2
# <ipython-input-28-a717959844e5>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Arousal_recorded']=Arousal_recorded_1_2
# <ipython-input-28-a717959844e5>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Dominance']=Dominance_1_2
# <ipython-input-28-a717959844e5>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Stress']=Stress_1_2
# <ipython-input-28-a717959844e5>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalEffort']=MentalEffort_1_2
# <ipython-input-28-a717959844e5>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalDemand']=MentalDemand_1_2
# <ipython-input-28-a717959844e5>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['PhysicalDemand']=PhysicalDemand_1_2
# <ipython-input-28-a717959844e5>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['TemporalDemand']=TemporalDemand_1_2
# <ipython-input-28-a717959844e5>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Effort']=Effort_1_2
# <ipython-input-28-a717959844e5>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance']=Performance_1_2
# <ipython-input-28-a717959844e5>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance_recorded']=Performance_recorded_1_2
# <ipython-input-28-a717959844e5>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Frustration']=Frustration_1_2
# <ipython-input-28-a717959844e5>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Condition']=Condition_1_2
# <ipython-input-28-a717959844e5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Valence_recorded']=Valence_recorded_1_2
# <ipython-input-28-a717959844e5>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Arousal_recorded']=Arousal_recorded_1_2
# <ipython-input-28-a717959844e5>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Dominance']=Dominance_1_2
# <ipython-input-28-a717959844e5>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Stress']=Stress_1_2
# <ipython-input-28-a717959844e5>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalEffort']=MentalEffort_1_2
# <ipython-input-28-a717959844e5>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalDemand']=MentalDemand_1_2
# <ipython-input-28-a717959844e5>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['PhysicalDemand']=PhysicalDemand_1_2
# <ipython-input-28-a717959844e5>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['TemporalDemand']=TemporalDemand_1_2
# <ipython-input-28-a717959844e5>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Effort']=Effort_1_2
# <ipython-input-28-a717959844e5>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance']=Performance_1_2
# <ipython-input-28-a717959844e5>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance_recorded']=Performance_recorded_1_2
# <ipython-input-28-a717959844e5>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Frustration']=Frustration_1_2
# <ipython-input-28-a717959844e5>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Condition']=Condition_1_2
# <ipython-input-28-a717959844e5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Valence_recorded']=Valence_recorded_1_2
# <ipython-input-28-a717959844e5>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Arousal_recorded']=Arousal_recorded_1_2
# <ipython-input-28-a717959844e5>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Dominance']=Dominance_1_2
# <ipython-input-28-a717959844e5>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Stress']=Stress_1_2
# <ipython-input-28-a717959844e5>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalEffort']=MentalEffort_1_2
# <ipython-input-28-a717959844e5>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalDemand']=MentalDemand_1_2
# <ipython-input-28-a717959844e5>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['PhysicalDemand']=PhysicalDemand_1_2
# <ipython-input-28-a717959844e5>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['TemporalDemand']=TemporalDemand_1_2
# <ipython-input-28-a717959844e5>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Effort']=Effort_1_2
# <ipython-input-28-a717959844e5>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance']=Performance_1_2
# <ipython-input-28-a717959844e5>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance_recorded']=Performance_recorded_1_2
# <ipython-input-28-a717959844e5>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Frustration']=Frustration_1_2
# <ipython-input-28-a717959844e5>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Condition']=Condition_1_2
# <ipython-input-28-a717959844e5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['TemporalDemand']=TemporalDemand_1_2
# <ipython-input-28-a717959844e5>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Effort']=Effort_1_2
# <ipython-input-28-a717959844e5>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance']=Performance_1_2
# <ipython-input-28-a717959844e5>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance_recorded']=Performance_recorded_1_2
# <ipython-input-28-a717959844e5>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Frustration']=Frustration_1_2
# <ipython-input-28-a717959844e5>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Condition']=Condition_1_2
# <ipython-input-28-a717959844e5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Valence_recorded']=Valence_recorded_1_2
# <ipython-input-28-a717959844e5>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Arousal_recorded']=Arousal_recorded_1_2
# <ipython-input-28-a717959844e5>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Dominance']=Dominance_1_2
# <ipython-input-28-a717959844e5>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Stress']=Stress_1_2
# <ipython-input-28-a717959844e5>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalEffort']=MentalEffort_1_2
# <ipython-input-28-a717959844e5>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalDemand']=MentalDemand_1_2
# <ipython-input-28-a717959844e5>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['PhysicalDemand']=PhysicalDemand_1_2
# <ipython-input-28-a717959844e5>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['TemporalDemand']=TemporalDemand_1_2
# <ipython-input-28-a717959844e5>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Effort']=Effort_1_2
# <ipython-input-28-a717959844e5>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance']=Performance_1_2
# <ipython-input-28-a717959844e5>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance_recorded']=Performance_recorded_1_2
# <ipython-input-28-a717959844e5>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Frustration']=Frustration_1_2
# <ipython-input-28-a717959844e5>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Condition']=Condition_1_2
# <ipython-input-28-a717959844e5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Valence_recorded']=Valence_recorded_1_2
# <ipython-input-28-a717959844e5>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Arousal_recorded']=Arousal_recorded_1_2
# <ipython-input-28-a717959844e5>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Dominance']=Dominance_1_2
# <ipython-input-28-a717959844e5>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Stress']=Stress_1_2
# <ipython-input-28-a717959844e5>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalEffort']=MentalEffort_1_2
# <ipython-input-28-a717959844e5>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalDemand']=MentalDemand_1_2
# <ipython-input-28-a717959844e5>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['PhysicalDemand']=PhysicalDemand_1_2
# <ipython-input-28-a717959844e5>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['TemporalDemand']=TemporalDemand_1_2
# <ipython-input-28-a717959844e5>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Effort']=Effort_1_2
# <ipython-input-28-a717959844e5>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance']=Performance_1_2
# <ipython-input-28-a717959844e5>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance_recorded']=Performance_recorded_1_2
# <ipython-input-28-a717959844e5>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Frustration']=Frustration_1_2
# <ipython-input-28-a717959844e5>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Condition']=Condition_1_2
# <ipython-input-28-a717959844e5>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Valence_recorded']=Valence_recorded_1_2
# <ipython-input-28-a717959844e5>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Arousal_recorded']=Arousal_recorded_1_2
# <ipython-input-28-a717959844e5>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Dominance']=Dominance_1_2
# <ipython-input-28-a717959844e5>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Stress']=Stress_1_2
# <ipython-input-28-a717959844e5>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalEffort']=MentalEffort_1_2
# <ipython-input-28-a717959844e5>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['MentalDemand']=MentalDemand_1_2
# <ipython-input-28-a717959844e5>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['PhysicalDemand']=PhysicalDemand_1_2
# <ipython-input-28-a717959844e5>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['TemporalDemand']=TemporalDemand_1_2
# <ipython-input-28-a717959844e5>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Effort']=Effort_1_2
# <ipython-input-28-a717959844e5>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance']=Performance_1_2
# <ipython-input-28-a717959844e5>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Performance_recorded']=Performance_recorded_1_2
# <ipython-input-28-a717959844e5>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Frustration']=Frustration_1_2

# %%
print(df_participant_dict['PP1']['block1'].shape)
print(df_participant_dict['PP1']['block2'].shape)
print(df_participant_dict['PP1']['block3'].shape)
# Out:
# (0, 81)
# (0, 81)
# (0, 81)

# %%
print(df_participant_dict['PP13']['block1'].shape)
print(df_participant_dict['PP13']['block2'].shape)
print(df_participant_dict['PP13']['block3'].shape)
# Out:
# (13468, 81)
# (9550, 81)
# (12532, 81)

# %%
df_list=[df_participant_dict['PP1']['block1'],df_participant_dict['PP1']['block2'],df_participant_dict['PP1']['block3'],df_participant_dict['PP2']['block1'],df_participant_dict['PP2']['block2'],df_participant_dict['PP2']['block3'],df_participant_dict['PP3']['block1'],df_participant_dict['PP3']['block2'],df_participant_dict['PP3']['block3'],df_participant_dict['PP4']['block1'],df_participant_dict['PP4']['block2'],df_participant_dict['PP4']['block3'],
df_participant_dict['PP5']['block1'],df_participant_dict['PP5']['block2'],df_participant_dict['PP5']['block3'],df_participant_dict['PP6']['block1'],df_participant_dict['PP6']['block2'],df_participant_dict['PP6']['block3'],df_participant_dict['PP7']['block1'],df_participant_dict['PP7']['block2'],
df_participant_dict['PP7']['block3'],df_participant_dict['PP8']['block1'],df_participant_dict['PP8']['block2'],df_participant_dict['PP8']['block3'],df_participant_dict['PP9']['block1'],
df_participant_dict['PP9']['block2'],df_participant_dict['PP9']['block3'],df_participant_dict['PP10']['block1'],df_participant_dict['PP10']['block2'],df_participant_dict['PP10']['block3'],df_participant_dict['PP11']['block1'],df_participant_dict['PP11']['block2'],df_participant_dict['PP11']['block3'],df_participant_dict['PP12']['block1'],df_participant_dict['PP12']['block2'],df_participant_dict['PP12']['block3'],
df_participant_dict['PP13']['block1'],df_participant_dict['PP13']['block2'],df_participant_dict['PP13']['block3'],df_participant_dict['PP14']['block1'],df_participant_dict['PP14']['block2'],df_participant_dict['PP14']['block3'],df_participant_dict['PP15']['block1'],df_participant_dict['PP15']['block2'],
df_participant_dict['PP15']['block3'],df_participant_dict['PP16']['block1'],df_participant_dict['PP16']['block2'],df_participant_dict['PP16']['block3'],df_participant_dict['PP17']['block1'], 
df_participant_dict['PP17']['block2'],df_participant_dict['PP17']['block3'],df_participant_dict['PP18']['block1'],df_participant_dict['PP18']['block2'],df_participant_dict['PP18']['block3'],df_participant_dict['PP19']['block1'],df_participant_dict['PP19']['block2'],df_participant_dict['PP19']['block3'],df_participant_dict['PP20']['block1'],df_participant_dict['PP20']['block2'],df_participant_dict['PP20']['block3'],
df_participant_dict['PP21']['block1'],df_participant_dict['PP21']['block2'],df_participant_dict['PP21']['block3'],df_participant_dict['PP22']['block1'],df_participant_dict['PP22']['block2'],df_participant_dict['PP22']['block3'],df_participant_dict['PP23']['block1'],df_participant_dict['PP23']['block2'],
df_participant_dict['PP23']['block3'],df_participant_dict['PP24']['block1'],df_participant_dict['PP24']['block2'],df_participant_dict['PP24']['block3'],df_participant_dict['PP25']['block1'],df_participant_dict['PP25']['block2'],df_participant_dict['PP25']['block3']]

# %%
len(df_list)
# Out:
# 75

# %%
#concatenate multiple data frames
df = pd.concat(df_list, axis=0)
df.shape
# Out:
# (651655, 81)

# %%
df.head(20)
# Out:
#        timestampSkeletal Spine ShoulderCenter Head ShoulderLeft ShoulderRight  \
# 40                     0   NaN            NaN  NaN          NaN           NaN
# 41                     0   NaN            NaN  NaN          NaN           NaN
# 479786          82472659   NaN            NaN  NaN          NaN           NaN
# 479787          82472859   NaN            NaN  NaN          NaN           NaN
# 479788          82473261   NaN            NaN  NaN          NaN           NaN
# 479789          82473461   NaN            NaN  NaN          NaN           NaN
# 479790          82473662   NaN            NaN  NaN          NaN           NaN
# 479791          82473859   NaN            NaN  NaN          NaN           NaN
# 479792          82474261   NaN            NaN  NaN          NaN           NaN
# 479793          82474461   NaN            NaN  NaN          NaN           NaN
# 479794          82474663   NaN            NaN  NaN          NaN           NaN
# 479795          82474859   NaN            NaN  NaN          NaN           NaN
# 479796          82475263   NaN            NaN  NaN          NaN           NaN
# 479797          82475463   NaN            NaN  NaN          NaN           NaN
# 479798          82475659   NaN            NaN  NaN          NaN           NaN
# 479799          82475861   NaN            NaN  NaN          NaN           NaN
# 479800          82476263   NaN            NaN  NaN          NaN           NaN
# 479801          82476461   NaN            NaN  NaN          NaN           NaN
# 479802          82476663   NaN            NaN  NaN          NaN           NaN
# 479803          82476863   NaN            NaN  NaN          NaN           NaN
#
#        ElbowLeft WristLeft HandLeft ElbowRight  ... Dominance Stress  \
# 40           NaN       NaN      NaN        NaN  ...       2.0    1.4
# 41           NaN       NaN      NaN        NaN  ...       2.0    1.4
# 479786       NaN       NaN      NaN        NaN  ...       2.0    1.4
# 479787       NaN       NaN      NaN        NaN  ...       2.0    1.4
# 479788       NaN       NaN      NaN        NaN  ...       2.0    1.4
# 479789       NaN       NaN      NaN        NaN  ...       2.0    1.4
# 479790       NaN       NaN      NaN        NaN  ...       2.0    1.4
# 479791       NaN       NaN      NaN        NaN  ...       2.0    1.4
# 479792       NaN       NaN      NaN        NaN  ...       2.0    1.4
# 479793       NaN       NaN      NaN        NaN  ...       2.0    1.4
# 479794       NaN       NaN      NaN        NaN  ...       2.0    1.4
# 479795       NaN       NaN      NaN        NaN  ...       2.0    1.4
# 479796       NaN       NaN      NaN        NaN  ...       2.0    1.4
# 479797       NaN       NaN      NaN        NaN  ...       2.0    1.4
# 479798       NaN       NaN      NaN        NaN  ...       2.0    1.4
# 479799       NaN       NaN      NaN        NaN  ...       2.0    1.4
# 479800       NaN       NaN      NaN        NaN  ...       2.0    1.4
# 479801       NaN       NaN      NaN        NaN  ...       2.0    1.4
# 479802       NaN       NaN      NaN        NaN  ...       2.0    1.4
# 479803       NaN       NaN      NaN        NaN  ...       2.0    1.4
#
#        MentalEffort MentalDemand PhysicalDemand TemporalDemand Effort  \
# 40              1.3          2.4            4.5            6.5    3.5
# 41              1.3          2.4            4.5            6.5    3.5
# 479786          1.3          2.4            4.5            6.5    3.5
# 479787          1.3          2.4            4.5            6.5    3.5
# 479788          1.3          2.4            4.5            6.5    3.5
# 479789          1.3          2.4            4.5            6.5    3.5
# 479790          1.3          2.4            4.5            6.5    3.5
# 479791          1.3          2.4            4.5            6.5    3.5
# 479792          1.3          2.4            4.5            6.5    3.5
# 479793          1.3          2.4            4.5            6.5    3.5
# 479794          1.3          2.4            4.5            6.5    3.5
# 479795          1.3          2.4            4.5            6.5    3.5
# 479796          1.3          2.4            4.5            6.5    3.5
# 479797          1.3          2.4            4.5            6.5    3.5
# 479798          1.3          2.4            4.5            6.5    3.5
# 479799          1.3          2.4            4.5            6.5    3.5
# 479800          1.3          2.4            4.5            6.5    3.5
# 479801          1.3          2.4            4.5            6.5    3.5
# 479802          1.3          2.4            4.5            6.5    3.5
# 479803          1.3          2.4            4.5            6.5    3.5
#
#        Performance Performance_recorded Frustration
# 40             5.0                  5.0         1.0
# 41             5.0                  5.0         1.0
# 479786         5.0                  5.0         1.0
# 479787         5.0                  5.0         1.0
# 479788         5.0                  5.0         1.0
# 479789         5.0                  5.0         1.0
# 479790         5.0                  5.0         1.0
# 479791         5.0                  5.0         1.0
# 479792         5.0                  5.0         1.0
# 479793         5.0                  5.0         1.0
# 479794         5.0                  5.0         1.0
# 479795         5.0                  5.0         1.0
# 479796         5.0                  5.0         1.0
# 479797         5.0                  5.0         1.0
# 479798         5.0                  5.0         1.0
# 479799         5.0                  5.0         1.0
# 479800         5.0                  5.0         1.0
# 479801         5.0                  5.0         1.0
# 479802         5.0                  5.0         1.0
# 479803         5.0                  5.0         1.0
#
# [20 rows x 81 columns]

# %%
df.columns
# Out:
# Index(['timestampSkeletal', 'Spine', 'ShoulderCenter', 'Head', 'ShoulderLeft',
#        'ShoulderRight', 'ElbowLeft', 'WristLeft', 'HandLeft', 'ElbowRight',
#        'WristRight', 'HandRight', 'HipCenter', 'HipLeft', 'HipRight',
#        'KneeLeft', 'AnkleLeft', 'FootLeft', 'KneeRight', 'AnkleRight',
#        'FootRight', 'Video Time', 'Neutral', 'Happy', 'Sad', 'Angry',
#        'Surprised', 'Scared', 'Disgusted', 'Valence', 'Gender', 'Age', 'Beard',
#        'Moustache', 'Glasses', 'Ethnicity', 'Y - Head Orientation',
#        'X - Head Orientation', 'Z - Head Orientation', 'Landmarks', 'Quality',
#        'Mouth', 'Left Eye', 'Right Eye', 'Left Eyebrow', 'Right Eyebrow',
#        'Gaze Direction', 'Action Unit 01 - Inner Brow Raiser',
#        'Action Unit 02 - Outer Brow Raiser', 'Action Unit 04 - Brow Lowerer',
#        'Action Unit 05 - Upper Lid Raiser', 'Action Unit 06 - Cheek Raiser',
#        'Action Unit 07 - Lid Tightener', 'Action Unit 09 - Nose Wrinkler',
#        'Action Unit 10 - Upper Lip Raiser',
#        'Action Unit 12 - Lip Corner Puller', 'Action Unit 14 - Dimpler',
#        'Action Unit 15 - Lip Corner Depressor', 'Action Unit 17 - Chin Raiser',
#        'Action Unit 20 - Lip Stretcher', 'Action Unit 23 - Lip Tightener',
#        'Action Unit 24 - Lip Pressor', 'Action Unit 25 - Lips Part',
#        'Action Unit 26 - Jaw Drop', 'Action Unit 27 - Mouth Stretch',
#        'Action Unit 43 - Eyes Closed', 'PP', 'Block', 'Condition',
#        'Valence_recorded', 'Arousal_recorded', 'Dominance', 'Stress',
#        'MentalEffort', 'MentalDemand', 'PhysicalDemand', 'TemporalDemand',
#        'Effort', 'Performance', 'Performance_recorded', 'Frustration'],
#       dtype='object')

# %%
column_list=['PP', 'Block', 'Condition','timestampSkeletal', 'Spine', 'ShoulderCenter', 'Head', 'ShoulderLeft',
       'ShoulderRight', 'ElbowLeft', 'WristLeft', 'HandLeft', 'ElbowRight',
       'WristRight', 'HandRight', 'HipCenter', 'HipLeft', 'HipRight',
       'KneeLeft', 'AnkleLeft', 'FootLeft', 'KneeRight', 'AnkleRight',
       'FootRight', 'Video Time', 'Neutral', 'Happy', 'Sad', 'Angry',
       'Surprised', 'Scared', 'Disgusted', 'Valence', 'Gender', 'Age', 'Beard',
       'Moustache', 'Glasses', 'Ethnicity', 'Y - Head Orientation',
       'X - Head Orientation', 'Z - Head Orientation', 'Landmarks', 'Quality',
       'Mouth', 'Left Eye', 'Right Eye', 'Left Eyebrow', 'Right Eyebrow',
       'Gaze Direction', 'Action Unit 01 - Inner Brow Raiser',
       'Action Unit 02 - Outer Brow Raiser', 'Action Unit 04 - Brow Lowerer',
       'Action Unit 05 - Upper Lid Raiser', 'Action Unit 06 - Cheek Raiser',
       'Action Unit 07 - Lid Tightener', 'Action Unit 09 - Nose Wrinkler',
       'Action Unit 10 - Upper Lip Raiser',
       'Action Unit 12 - Lip Corner Puller', 'Action Unit 14 - Dimpler',
       'Action Unit 15 - Lip Corner Depressor', 'Action Unit 17 - Chin Raiser',
       'Action Unit 20 - Lip Stretcher', 'Action Unit 23 - Lip Tightener',
       'Action Unit 24 - Lip Pressor', 'Action Unit 25 - Lips Part',
       'Action Unit 26 - Jaw Drop', 'Action Unit 27 - Mouth Stretch',
       'Action Unit 43 - Eyes Closed', 
       'Valence_recorded', 'Arousal_recorded', 'Dominance', 'Stress',
       'MentalEffort', 'MentalDemand', 'PhysicalDemand', 'TemporalDemand',
       'Effort', 'Performance', 'Performance_recorded', 'Frustration']
print(len(column_list))
# Out:
# 81

# %%
df=df[column_list]

# %%
df.shape
# Out:
# (651655, 81)

# %%
df.head(20)
# Out:
#          PP  Block Condition timestampSkeletal Spine ShoulderCenter Head  \
# 40      PP2    1.0         N                 0   NaN            NaN  NaN
# 41      PP2    1.0         N                 0   NaN            NaN  NaN
# 479786  PP2    1.0         N          82472659   NaN            NaN  NaN
# 479787  PP2    1.0         N          82472859   NaN            NaN  NaN
# 479788  PP2    1.0         N          82473261   NaN            NaN  NaN
# 479789  PP2    1.0         N          82473461   NaN            NaN  NaN
# 479790  PP2    1.0         N          82473662   NaN            NaN  NaN
# 479791  PP2    1.0         N          82473859   NaN            NaN  NaN
# 479792  PP2    1.0         N          82474261   NaN            NaN  NaN
# 479793  PP2    1.0         N          82474461   NaN            NaN  NaN
# 479794  PP2    1.0         N          82474663   NaN            NaN  NaN
# 479795  PP2    1.0         N          82474859   NaN            NaN  NaN
# 479796  PP2    1.0         N          82475263   NaN            NaN  NaN
# 479797  PP2    1.0         N          82475463   NaN            NaN  NaN
# 479798  PP2    1.0         N          82475659   NaN            NaN  NaN
# 479799  PP2    1.0         N          82475861   NaN            NaN  NaN
# 479800  PP2    1.0         N          82476263   NaN            NaN  NaN
# 479801  PP2    1.0         N          82476461   NaN            NaN  NaN
# 479802  PP2    1.0         N          82476663   NaN            NaN  NaN
# 479803  PP2    1.0         N          82476863   NaN            NaN  NaN
#
#        ShoulderLeft ShoulderRight ElbowLeft  ... Dominance Stress  \
# 40              NaN           NaN       NaN  ...       2.0    1.4
# 41              NaN           NaN       NaN  ...       2.0    1.4
# 479786          NaN           NaN       NaN  ...       2.0    1.4
# 479787          NaN           NaN       NaN  ...       2.0    1.4
# 479788          NaN           NaN       NaN  ...       2.0    1.4
# 479789          NaN           NaN       NaN  ...       2.0    1.4
# 479790          NaN           NaN       NaN  ...       2.0    1.4
# 479791          NaN           NaN       NaN  ...       2.0    1.4
# 479792          NaN           NaN       NaN  ...       2.0    1.4
# 479793          NaN           NaN       NaN  ...       2.0    1.4
# 479794          NaN           NaN       NaN  ...       2.0    1.4
# 479795          NaN           NaN       NaN  ...       2.0    1.4
# 479796          NaN           NaN       NaN  ...       2.0    1.4
# 479797          NaN           NaN       NaN  ...       2.0    1.4
# 479798          NaN           NaN       NaN  ...       2.0    1.4
# 479799          NaN           NaN       NaN  ...       2.0    1.4
# 479800          NaN           NaN       NaN  ...       2.0    1.4
# 479801          NaN           NaN       NaN  ...       2.0    1.4
# 479802          NaN           NaN       NaN  ...       2.0    1.4
# 479803          NaN           NaN       NaN  ...       2.0    1.4
#
#        MentalEffort MentalDemand PhysicalDemand TemporalDemand Effort  \
# 40              1.3          2.4            4.5            6.5    3.5
# 41              1.3          2.4            4.5            6.5    3.5
# 479786          1.3          2.4            4.5            6.5    3.5
# 479787          1.3          2.4            4.5            6.5    3.5
# 479788          1.3          2.4            4.5            6.5    3.5
# 479789          1.3          2.4            4.5            6.5    3.5
# 479790          1.3          2.4            4.5            6.5    3.5
# 479791          1.3          2.4            4.5            6.5    3.5
# 479792          1.3          2.4            4.5            6.5    3.5
# 479793          1.3          2.4            4.5            6.5    3.5
# 479794          1.3          2.4            4.5            6.5    3.5
# 479795          1.3          2.4            4.5            6.5    3.5
# 479796          1.3          2.4            4.5            6.5    3.5
# 479797          1.3          2.4            4.5            6.5    3.5
# 479798          1.3          2.4            4.5            6.5    3.5
# 479799          1.3          2.4            4.5            6.5    3.5
# 479800          1.3          2.4            4.5            6.5    3.5
# 479801          1.3          2.4            4.5            6.5    3.5
# 479802          1.3          2.4            4.5            6.5    3.5
# 479803          1.3          2.4            4.5            6.5    3.5
#
#        Performance Performance_recorded Frustration
# 40             5.0                  5.0         1.0
# 41             5.0                  5.0         1.0
# 479786         5.0                  5.0         1.0
# 479787         5.0                  5.0         1.0
# 479788         5.0                  5.0         1.0
# 479789         5.0                  5.0         1.0
# 479790         5.0                  5.0         1.0
# 479791         5.0                  5.0         1.0
# 479792         5.0                  5.0         1.0
# 479793         5.0                  5.0         1.0
# 479794         5.0                  5.0         1.0
# 479795         5.0                  5.0         1.0
# 479796         5.0                  5.0         1.0
# 479797         5.0                  5.0         1.0
# 479798         5.0                  5.0         1.0
# 479799         5.0                  5.0         1.0
# 479800         5.0                  5.0         1.0
# 479801         5.0                  5.0         1.0
# 479802         5.0                  5.0         1.0
# 479803         5.0                  5.0         1.0
#
# [20 rows x 81 columns]

# %%
#save pd data frame to a csv file
df.to_csv(r"C:\Users\sivaluxan\Desktop\FYP-2021\FYP\ENTC_17_FYP_26\stress_data_collection\updated_dataset_1\combine\data_with_questionnaire.csv",index=False)
