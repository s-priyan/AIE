# %% [markdown]
# # Load the  models

# %%
# import numpy as np
from feat.detector import Detector
face_model = "retinaface"
landmark_model = "pfld"
au_model = "jaanet"
emotion_model = "resmasknet"
detector = Detector(face_model = face_model, landmark_model = landmark_model, au_model = au_model, emotion_model = emotion_model)
# Out:
# C:\ProgramData\Anaconda3\envs\pytorch_2\lib\site-packages\nilearn\datasets\__init__.py:96: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   "Numpy arrays.", FutureWarning)
# Loading Face Detection model:  retinaface
# ...
#   0%|          | 0/93520369 [00:00<?, ?it/s]

# %% [markdown]
# # feature extraction on images

# %%
test_image  = "F:/FinalYearProject/facial-feature-extractor/feat/tests/data/stess3.png"
image_prediction = detector.detect_image(test_image)
# Show results
image_prediction
# Out:
#    frame   FaceRectX  FaceRectY  FaceRectWidth  FaceRectHeight  FaceScore  \
# 0    0.0  275.790741  103.58625     199.401642       275.08606   0.999665
#
#           x_0         x_1        x_2         x_3  ...      Roll       Yaw  \
# 0  278.077574  280.157329  284.79077  291.590395  ... -0.929004  5.825266
#
#      anger   disgust      fear  happiness  sadness  surprise   neutral  \
# 0  0.00565  0.000013  0.000022   0.000932  0.00184  0.026486  0.965057
#
#                                                input
# 0  F:/FinalYearProject/facial-feature-extractor/f...
#
# [1 rows x 165 columns]

# %%
image_prediction.plot_detections()
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001EE429B6250>,
# ...
#       dtype=object)

# %%
test_image  = "F:/FinalYearProject/facial-feature-extractor/feat/tests/data/stress.soori.png"
image_prediction = detector.detect_image(test_image)
# Show results
image_prediction
# Out:
#    frame   FaceRectX   FaceRectY  FaceRectWidth  FaceRectHeight  FaceScore  \
# 0    0.0  245.331299  130.004227     238.582764      317.892883   0.999875
#
#           x_0         x_1         x_2         x_3  ...      Roll       Yaw  \
# 0  249.751673  252.195247  257.377551  264.887358  ... -1.448588  3.042458
#
#       anger  disgust      fear  happiness   sadness  surprise   neutral  \
# 0  0.178847  0.01218  0.027777   0.000709  0.015058  0.134669  0.630761
#
#                                                input
# 0  F:/FinalYearProject/facial-feature-extractor/f...
#
# [1 rows x 165 columns]

# %%
image_prediction.plot_detections()
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001EE42BF79A0>,
# ...
#       dtype=object)

# %%
test_image  = "F:/FinalYearProject/facial-feature-extractor/feat/tests/data/stress.soori.png"
image_prediction = detector.detect_image(test_image)
# Show results
image_prediction

# %%
image_prediction.plot_detections()

# %%
test_image  = "F:/FinalYearProject/facial-feature-extractor/feat/tests/data/priyan.jpg"
image_prediction = detector.detect_image(test_image)
# Show results
image_prediction
# Out:
#    frame   FaceRectX  FaceRectY  FaceRectWidth  FaceRectHeight  FaceScore  \
# 0    0.0  268.921783  75.508812     126.255524      175.869171   0.999732
#
#          x_0         x_1         x_2        x_3  ...      Roll       Yaw  \
# 0  265.00651  266.748703  269.795362  274.60115  ... -3.990332  0.758113
#
#       anger   disgust      fear  happiness   sadness  surprise   neutral  \
# 0  0.000366  0.000148  0.010719   0.917625  0.000249  0.070117  0.000775
#
#                                                input
# 0  F:/FinalYearProject/facial-feature-extractor/f...
#
# [1 rows x 165 columns]

# %%
image_prediction.plot_detections()
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001EE0A65A4F0>,
# ...
#       dtype=object)

# %%
image_prediction.head()
# Out:
#    frame   FaceRectX  FaceRectY  FaceRectWidth  FaceRectHeight  FaceScore  \
# 0    0.0  268.921783  75.508812     126.255524      175.869171   0.999732
#
#          x_0         x_1         x_2        x_3  ...      Roll       Yaw  \
# 0  265.00651  266.748703  269.795362  274.60115  ... -3.990332  0.758113
#
#       anger   disgust      fear  happiness   sadness  surprise   neutral  \
# 0  0.000366  0.000148  0.010719   0.917625  0.000249  0.070117  0.000775
#
#                                                input
# 0  F:/FinalYearProject/facial-feature-extractor/f...
#
# [1 rows x 165 columns]

# %%
test_image  = "F:/FinalYearProject/facial-feature-extractor/feat/tests/data/stress4.png"
image_prediction = detector.detect_image(test_image)
# Show results
image_prediction
# Out:
#    frame   FaceRectX   FaceRectY  FaceRectWidth  FaceRectHeight  FaceScore  \
# 0    0.0  194.853897  144.659805     185.031693      246.172562   0.999751
#
#           x_0         x_1         x_2         x_3  ...      Roll       Yaw  \
# 0  191.940284  191.754451  193.591271  197.327482  ...  3.713847  0.194066
#
#       anger   disgust      fear  happiness   sadness  surprise   neutral  \
# 0  0.181819  0.069113  0.007938   0.241331  0.019123   0.04335  0.437326
#
#                                                input
# 0  F:/FinalYearProject/facial-feature-extractor/f...
#
# [1 rows x 165 columns]

# %%
image_prediction.plot_detections()
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000029AC0C30580>,
# ...
#       dtype=object)

# %% [markdown]
# # Detecting facial expressions on video and Data logging

# %%
detector.detect_video("F:/FinalYearProject/facial-feature-extractor/stress-detection/stress-video/non-stress.mp4", outputFname = "F:/FinalYearProject/facial-feature-extractor/stress-detection/validation-data/output.csv")
# Out:
# True
